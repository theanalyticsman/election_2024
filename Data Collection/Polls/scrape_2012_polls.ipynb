# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_polls_to_dataframe(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all tables containing poll data
        tables = soup.find_all('table', class_='wikitable')

        poll_data = []
        header_row = ['Poll source', 'Date administered', 'Democrat', '%', 'Republican', '%', 'Lead margin', 'Sample Size', 'Margin of error', 'state']
        poll_data.append(header_row)


        for table in tables:
            # Extract state name
            state_header = table.find_previous('h3')
            if state_header:
                state = state_header.text
                state = state.replace('[edit]','')
            else:
                continue

            # Extract rows from the table
            t = load_table(table, 'state',state)
            poll_count = 1
            for row in t:
                if row != header_row and len(row) == len(header_row):
                    if poll_count <= 15:
                        poll_data.append(row)
                        poll_count += 1
    
        return poll_data

    else:
        print("Error fetching the webpage. Status code:", response.status_code)
        return None

def load_table(table, descriptor_title = 'none', descriptor = 'none'):
    t = table
    table_data = []
    row_data = []
    rows = t.find_all('tr')
    heads = t.find_all('th')
    heads = [head.text.strip() for head in heads]
    if descriptor_title != 'none':
        heads.append(descriptor_title)
    
    table_data.append(heads)

    # print(heads)

    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        if descriptor != 'none':
            cols.append(descriptor)
        if len(cols) > 1:
            table_data.append(cols)         
    return table_data

# %%
url = 'https://en.wikipedia.org/wiki/Statewide_opinion_polling_for_the_2012_United_States_presidential_election'
polls = scrape_polls_to_dataframe(url)
polling = pd.DataFrame(polls)

# %%
polling.head()
polling.columns = polling.iloc[0]
polling = polling[1:]

# %%
polling.loc[polling.state == 'Michigan']
# Out:
# 0                                          Poll source  \
# 140                 Mitchell Research & Communications
# 141                          Angus Reid Public Opinion
# 142                              Public Policy Polling
# 143                                             YouGov
# 144  Fox 2 News Detroit/Foster McCollum White & Ass...
# 145                                  Rasmussen Reports
# 146     USAction/Project New America/Grove Insight (D)
# 147  League of Conservation Voters/Public Policy Po...
# 148  Health Care for America Now/Public Policy Poll...
# 149  Detroit News/Glengariff Group[permanent dead l...
# 150                                           EPIC-MRA
# 151  Fox 2 News Detroit/Foster McCollum White & Ass...
# 152                          Angus Reid Public Opinion
# 153                                           EPIC-MRA
# 154           Rasmussen Reports/Pulse Opinion Research
#
# 0                Date administered Democrat       % Republican       %  \
# 140               November 4, 2012    Obama     51%     Romney     46%
# 141           November 1 – 3, 2012    Obama     52%     Romney     47%
# 142           November 1 – 3, 2012    Obama     52%     Romney     46%
# 143  October 31 – November 3, 2012    Obama     51%     Romney     44%
# 144               November 2, 2012    Obama  46.24%     Romney  46.86%
# 145               November 1, 2012    Obama     52%     Romney     47%
# 146  October 31 – November 1, 2012    Obama     48%     Romney     41%
# 147  October 31 – November 1, 2012    Obama     52%     Romney     46%
# 148            October 30–31, 2012    Obama     53%     Romney     45%
# 149            October 27–29, 2012    Obama   47.7%     Romney     45%
# 150            October 26–29, 2012    Obama     48%     Romney     42%
# 151            October 22–23, 2012    Obama  46.92%     Romney  46.56%
# 152            October 18–20, 2012    Obama     52%     Romney     43%
# 153               October 17, 2012    Obama     52%     Romney     46%
# 154               October 11, 2012    Obama     52%     Romney     45%
#
# 0   Lead margin Sample Size Margin of error     state
# 140           5    1,305 LV           ±2.7%  Michigan
# 141           5      502 LV           ±4.4%  Michigan
# 142           6      700 LV           ±3.7%  Michigan
# 143           7    1,091 LV           ±3.3%  Michigan
# 144        0.62    1,913 LV          ±2.24%  Michigan
# 145           5      750 LV             ±4%  Michigan
# 146           7      500 LV           ±4.4%  Michigan
# 147           6      500 LV           ±4.4%  Michigan
# 148           8      500 LV           ±4.4%  Michigan
# 149         2.7      600 LV             ±4%  Michigan
# 150           6      600 LV             ±4%  Michigan
# 151        0.36    1,122 LV           ±2.9%  Michigan
# 152           9      551 LV           ±4.2%  Michigan
# 153           6      800 LV           ±3.5%  Michigan
# 154           7      500 LV           ±4.5%  Michigan

# %%
polling.columns.values[3] = 'DEM_PERCENT'
polling.columns.values[5] = 'GOP_PERCENT'

# %%
polling['DEM_PERCENT'] = pd.to_numeric(polling['DEM_PERCENT'].str.strip('%')) / 100
polling['GOP_PERCENT'] = pd.to_numeric(polling['GOP_PERCENT'].str.strip('%')) / 100

# %%
import duckdb
# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb
# Out:
# Deploy FastAPI apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
# %%sql
#
# SELECT
#     2012 as year,
#     state,
#     COUNT(*) as poll_count,
#     AVG(DEM_PERCENT) as dem_poll_avg,
#     AVG(GOP_PERCENT) as gop_poll_avg
# FROM polling
# GROUP BY state
# Out:
#     year                 state  poll_count  dem_poll_avg  gop_poll_avg
# 0   2012               Arizona          11      0.435455      0.503636
# 1   2012                  Iowa          15      0.482133      0.460333
# 2   2012             Louisiana           2      0.366000      0.559000
# 3   2012                  Ohio          15      0.492667      0.465333
# 4   2012          Rhode Island           3      0.565000      0.328000
# 5   2012                 Texas           5      0.394000      0.560000
# 6   2012            New Jersey           9      0.520000      0.402222
# 7   2012             Tennessee           4      0.402500      0.535000
# 8   2012             Wisconsin          15      0.500333      0.456533
# 9   2012            California          14      0.550214      0.371643
# 10  2012              Colorado          15      0.478000      0.466667
# 11  2012                Hawaii           2      0.615000      0.320000
# 12  2012              Illinois           6      0.566667      0.376667
# 13  2012          North Dakota           5      0.382000      0.540000
# 14  2012              Arkansas           2      0.327500      0.567500
# 15  2012                 Idaho           1      0.270000      0.630000
# 16  2012            New Mexico          14      0.501429      0.417143
# 17  2012            Washington          15      0.538000      0.400867
# 18  2012           Connecticut          14      0.531429      0.403571
# 19  2012               Indiana           8      0.421250      0.525000
# 20  2012                 Maine           6      0.525167      0.403333
# 21  2012              Maryland           5      0.574000      0.364000
# 22  2012         Massachusetts          15      0.563333      0.378667
# 23  2012                Oregon           5      0.490000      0.424000
# 24  2012              Kentucky           1      0.390000      0.530000
# 25  2012              New York           6      0.603333      0.346667
# 26  2012              Oklahoma           1      0.330000      0.590000
# 27  2012                  Utah           3      0.223333      0.713333
# 28  2012              Virginia          15      0.485000      0.463733
# 29  2012  District of Columbia           1      0.880000      0.080000
# 30  2012               Florida          15      0.476600      0.484533
# 31  2012               Georgia           6      0.426667      0.523333
# 32  2012             Minnesota          15      0.504667      0.434000
# 33  2012                Nevada          15      0.498667      0.457333
# 34  2012         New Hampshire          15      0.489333      0.466000
# 35  2012          South Dakota           4      0.412500      0.515000
# 36  2012              Michigan          15      0.503907      0.450947
# 37  2012              Missouri          14      0.436286      0.514571
# 38  2012               Montana           8      0.436250      0.517500
# 39  2012              Nebraska           5      0.414000      0.500000
# 40  2012        North Carolina          15      0.466000      0.485333
# 41  2012          Pennsylvania          15      0.497333      0.452000

# %%
query_output = """
SELECT 
    2012 as year,
    state,
    COUNT(*) as poll_count, 
    AVG(DEM_PERCENT) as dem_poll_avg,
    AVG(GOP_PERCENT) as gop_poll_avg
FROM polling
GROUP BY state
"""

# %%
polls_2012 = conn.execute(query_output).fetchall()
polls_2012_df = pd.DataFrame(polls_2012, columns= [col[0] for col in conn.description])

# %%
polls_2012_df
# Out:
#     year                 state  poll_count  dem_poll_avg  gop_poll_avg
# 0   2012               Arizona          11      0.435455      0.503636
# 1   2012                  Iowa          15      0.482133      0.460333
# 2   2012             Louisiana           2      0.366000      0.559000
# 3   2012                  Ohio          15      0.492667      0.465333
# 4   2012          Rhode Island           3      0.565000      0.328000
# 5   2012                 Texas           5      0.394000      0.560000
# 6   2012            California          14      0.550214      0.371643
# 7   2012              Colorado          15      0.478000      0.466667
# 8   2012                Hawaii           2      0.615000      0.320000
# 9   2012              Illinois           6      0.566667      0.376667
# 10  2012          North Dakota           5      0.382000      0.540000
# 11  2012            New Jersey           9      0.520000      0.402222
# 12  2012             Tennessee           4      0.402500      0.535000
# 13  2012             Wisconsin          15      0.500333      0.456533
# 14  2012           Connecticut          14      0.531429      0.403571
# 15  2012               Indiana           8      0.421250      0.525000
# 16  2012                 Maine           6      0.525167      0.403333
# 17  2012              Maryland           5      0.574000      0.364000
# 18  2012         Massachusetts          15      0.563333      0.378667
# 19  2012                Oregon           5      0.490000      0.424000
# 20  2012              Arkansas           2      0.327500      0.567500
# 21  2012                 Idaho           1      0.270000      0.630000
# 22  2012            New Mexico          14      0.501429      0.417143
# 23  2012            Washington          15      0.538000      0.400867
# 24  2012              Michigan          15      0.503907      0.450947
# 25  2012              Missouri          14      0.436286      0.514571
# 26  2012               Montana           8      0.436250      0.517500
# 27  2012              Nebraska           5      0.414000      0.500000
# 28  2012        North Carolina          15      0.466000      0.485333
# 29  2012          Pennsylvania          15      0.497333      0.452000
# 30  2012              Kentucky           1      0.390000      0.530000
# 31  2012              New York           6      0.603333      0.346667
# 32  2012              Oklahoma           1      0.330000      0.590000
# 33  2012                  Utah           3      0.223333      0.713333
# 34  2012              Virginia          15      0.485000      0.463733
# 35  2012  District of Columbia           1      0.880000      0.080000
# 36  2012               Florida          15      0.476600      0.484533
# 37  2012               Georgia           6      0.426667      0.523333
# 38  2012             Minnesota          15      0.504667      0.434000
# 39  2012                Nevada          15      0.498667      0.457333
# 40  2012         New Hampshire          15      0.489333      0.466000
# 41  2012          South Dakota           4      0.412500      0.515000

# %%
polls_2012_df.to_csv('C:/Users/appar/OneDrive/jup_nb/polls_2012.csv')
