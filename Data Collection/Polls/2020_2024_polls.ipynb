# %%
import requests
import pandas as pd
import duckdb
# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
polling_2020 = pd.read_csv('https://projects.fivethirtyeight.com/2020-general-data/presidential_polls_2020.csv')

# %%
polling_2020['enddate'] = pd.to_datetime(polling_2020['enddate'])
polling_2020.head()
# Out:
#    cycle    state  modeldate       candidate_name   startdate    enddate  \
# 0   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/20/2020 2020-11-01
# 1   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/18/2020 2020-10-31
# 2   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/17/2020 2020-10-30
# 3   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/16/2020 2020-10-29
# 4   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.   10/8/2020 2020-10-28
#
#                 pollster  samplesize population    weight  influence   pct  \
# 0           SurveyMonkey       330.0         lv  0.165557   0.165557  33.0
# 1           SurveyMonkey       361.0         lv  0.025764   0.025605  34.0
# 2           SurveyMonkey       378.0         lv  0.013440   0.013274  33.0
# 3           SurveyMonkey       394.0         lv  0.013962   0.013703  33.0
# 4  University of Wyoming       614.0         lv  0.681785   0.648074  31.0
#
#    house_adjusted_pct  trend_and_house_adjusted_pct tracking  poll_id  \
# 0            31.85685                      31.85630        T    72663
# 1            32.84583                      32.83956        T    72525
# 2            31.85685                      31.85175        T    72424
# 3            31.85685                      31.85221        T    72345
# 4            30.95937                      30.97865      NaN    72334
#
#    question_id
# 0       136416
# 1       136147
# 2       135950
# 3       135785
# 4       135714

# %%
# %%sql
#
# SELECT *
# FROM polling_2020
# LIMIT 5
# Out:
#    cycle    state  modeldate       candidate_name   startdate    enddate  \
# 0   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/20/2020 2020-11-01
# 1   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/18/2020 2020-10-31
# 2   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/17/2020 2020-10-30
# 3   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.  10/16/2020 2020-10-29
# 4   2020  Wyoming  11/3/2020  Joseph R. Biden Jr.   10/8/2020 2020-10-28
#
#                 pollster  samplesize population    weight  influence   pct  \
# 0           SurveyMonkey       330.0         lv  0.165557   0.165557  33.0
# 1           SurveyMonkey       361.0         lv  0.025764   0.025605  34.0
# 2           SurveyMonkey       378.0         lv  0.013440   0.013274  33.0
# 3           SurveyMonkey       394.0         lv  0.013962   0.013703  33.0
# 4  University of Wyoming       614.0         lv  0.681785   0.648074  31.0
#
#    house_adjusted_pct  trend_and_house_adjusted_pct tracking  poll_id  \
# 0            31.85685                      31.85630        T    72663
# 1            32.84583                      32.83956        T    72525
# 2            31.85685                      31.85175        T    72424
# 3            31.85685                      31.85221        T    72345
# 4            30.95937                      30.97865     None    72334
#
#    question_id
# 0       136416
# 1       136147
# 2       135950
# 3       135785
# 4       135714

# %%
# %%sql
#
# SELECT distinct candidate_name
# FROM polling_2020
# LIMIT 5
# Out:
#         candidate_name
# 0  Joseph R. Biden Jr.
# 1         Donald Trump

# %%
# %%sql
#
# WITH
#
# polling_raw as
# (
# SELECT *
# FROM
#     (SELECT
#         state,
#         CAST(enddate as DATE) as enddate,
#         poll_id,
#         question_id,
#         row_number() OVER (PARTITION BY state ORDER BY CAST(enddate as DATE) DESC) as poll_number,
#         SUM(CASE WHEN candidate_name = 'Joseph R. Biden Jr.' then pct else 0 END) as BIDEN,
#         SUM(CASE WHEN candidate_name = 'Donald Trump' then pct else 0 END) as TRUMP,
#     FROM polling_2020
#     GROUP BY
#         state,
#         enddate,
#         poll_id,
#         question_id
#     )
# ORDER BY CAST(enddate as DATE) DESC
# )
#
# SELECT
#     state,
#     avg(BIDEN) as dem_poll_avg,
#     avg(TRUMP) as gop_poll_avg
# FROM polling_raw
# WHERE poll_number >= 15
# GROUP BY
#     state
# Out:
#                    state  dem_poll_avg  gop_poll_avg
# 0                Arizona     48.604206     45.230397
# 1                   Ohio     46.572951     48.356066
# 2                  Texas     45.990000     48.061529
# 3                   Iowa     46.978302     47.796415
# 4                 Kansas     43.937391     51.763043
# 5              Louisiana     39.378125     56.770000
# 6           Rhode Island     64.348000     34.550000
# 7               National     50.146539     42.575943
# 8                Indiana     42.606316     53.514737
# 9                  Maine     54.172333     40.805000
# 10              Maryland     64.437647     32.188235
# 11           Connecticut     59.396471     34.577647
# 12         Massachusetts     66.939444     28.792222
# 13                Oregon     59.272308     38.250769
# 14              Colorado     54.142000     40.360000
# 15              Illinois     58.956667     38.342000
# 16               Alabama     38.133182     58.465455
# 17            California     61.076944     32.905556
# 18           Mississippi     39.443529     57.125882
# 19                Hawaii     63.670000     32.711667
# 20          North Dakota     36.385000     60.112143
# 21              Delaware     62.584615     34.387692
# 22             Wisconsin     49.712481     43.349847
# 23            New Jersey     57.644800     36.150400
# 24             Tennessee     39.637143     57.207143
# 25              Virginia     53.024242     41.550909
# 26              Kentucky     38.995417     56.873333
# 27              New York     62.227000     32.706000
# 28              Oklahoma     36.890556     59.143889
# 29                  Utah     39.778000     52.356500
# 30               Wyoming     31.712727     67.093636
# 31          Pennsylvania     49.749879     44.611818
# 32              Michigan     50.000455     42.909481
# 33        North Carolina     48.319384     46.034795
# 34              Missouri     44.619231     51.597692
# 35               Montana     42.977419     52.392258
# 36              Nebraska     44.832000     53.412000
# 37               Florida     48.601458     46.029861
# 38               Georgia     47.390349     47.106163
# 39             Minnesota     52.056981     42.409434
# 40                Nevada     49.312000     45.306333
# 41         New Hampshire     52.882000     42.656571
# 42          South Dakota     41.890833     56.309167
# 43                Alaska     44.386842     51.696316
# 44               Vermont     66.696667     30.690833
# 45  District of Columbia     87.382000     10.455000
# 46        South Carolina     44.190882     51.350000
# 47            New Mexico     52.832353     44.113529
# 48            Washington     59.703684     35.822632
# 49              Arkansas     37.992308     59.140769
# 50         West Virginia     33.810714     63.600714
# 51                 Idaho     38.216364     59.420909
# 52                  ME-2     45.000000     42.000000

# %%
query = """
WITH

polling_raw as 
(
SELECT *
FROM
    (SELECT 
        state,
        CAST(enddate as DATE) as enddate,
        poll_id, 
        question_id,
        row_number() OVER (PARTITION BY state ORDER BY CAST(enddate as DATE) DESC) as poll_number,
        SUM(CASE WHEN candidate_name = 'Joseph R. Biden Jr.' then pct else 0 END) as BIDEN,
        SUM(CASE WHEN candidate_name = 'Donald Trump' then pct else 0 END) as TRUMP,
    FROM polling_2020
    GROUP BY 
        state,
        enddate,
        poll_id, 
        question_id
    )
ORDER BY CAST(enddate as DATE) DESC
)

SELECT 
    state, 
    avg(BIDEN) as dem_poll_avg, 
    avg(TRUMP) as gop_poll_avg
FROM polling_raw
WHERE poll_number >= 15
GROUP BY
    state
"""

# %%
result = conn.execute(query)

# %%
polling_2020_updated = pd.DataFrame(result.fetchall(), columns=[x[0] for x in result.description])
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
polling_2020_updated.head()
# Out:
#      state  dem_poll_avg  gop_poll_avg
# 0  Arizona     48.604206     45.230397
# 1     Ohio     46.572951     48.323279
# 2    Texas     45.990000     48.085059
# 3     Iowa     46.978302     47.796415
# 4   Kansas     43.980870     52.023913

# %%
polling_2020_updated.to_csv('C:/Users/appar/OneDrive/jup_nb/polls_2020.csv')

# %%
polling_2024_url = 'https://projects.fivethirtyeight.com/polls-page/data/president_polls.csv'

# %%
polling_2024_initial = pd.read_csv(polling_2024_url)

# %%
# %%sql
#
# SELECT *
# FROM polling_2024_initial
# LIMIT 5
# Out:
#    poll_id  pollster_id   pollster sponsor_ids sponsors  \
# 0    86653         1424  Siena/NYT        None     None
# 1    86653         1424  Siena/NYT        None     None
# 2    86653         1424  Siena/NYT        None     None
# 3    86653         1424  Siena/NYT        None     None
# 4    86653         1424  Siena/NYT        None     None
#
#                        display_name  pollster_rating_id  \
# 0  The New York Times/Siena College                 448
# 1  The New York Times/Siena College                 448
# 2  The New York Times/Siena College                 448
# 3  The New York Times/Siena College                 448
# 4  The New York Times/Siena College                 448
#
#                pollster_rating_name  numeric_grade  pollscore  ...  \
# 0  The New York Times/Siena College            3.0       -1.5  ...
# 1  The New York Times/Siena College            3.0       -1.5  ...
# 2  The New York Times/Siena College            3.0       -1.5  ...
# 3  The New York Times/Siena College            3.0       -1.5  ...
# 4  The New York Times/Siena College            3.0       -1.5  ...
#
#   election_date    stage nationwide_batch ranked_choice_reallocated  \
# 0       11/5/24  general            False                     False
# 1       11/5/24  general            False                     False
# 2       11/5/24  general            False                     False
# 3       11/5/24  general            False                     False
# 4       11/5/24  general            False                     False
#
#   ranked_choice_round  party   answer candidate_id     candidate_name   pct
# 0                 NaN    DEM    Biden        19368          Joe Biden  45.0
# 1                 NaN    REP    Trump        16651       Donald Trump  46.0
# 2                 NaN    DEM    Biden        19368          Joe Biden  40.0
# 3                 NaN    REP    Trump        16651       Donald Trump  42.0
# 4                 NaN    IND  Kennedy        31042  Robert F. Kennedy   2.0
#
# [5 rows x 48 columns]

# %%
polling_2024_initial.dtypes
polling_2024_initial['end_date'] = pd.to_datetime(polling_2024_initial['end_date'])
# Out:
# C:\Users\appar\AppData\Local\Temp\ipykernel_25716\349816578.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   polling_2024_initial['end_date'] = pd.to_datetime(polling_2024_initial['end_date'])

# %%
polling_2024_initial.head()
# Out:
#    poll_id  pollster_id   pollster sponsor_ids sponsors  \
# 0    86653         1424  Siena/NYT         NaN      NaN
# 1    86653         1424  Siena/NYT         NaN      NaN
# 2    86653         1424  Siena/NYT         NaN      NaN
# 3    86653         1424  Siena/NYT         NaN      NaN
# 4    86653         1424  Siena/NYT         NaN      NaN
#
#                        display_name  pollster_rating_id  \
# 0  The New York Times/Siena College                 448
# 1  The New York Times/Siena College                 448
# 2  The New York Times/Siena College                 448
# 3  The New York Times/Siena College                 448
# 4  The New York Times/Siena College                 448
#
#                pollster_rating_name  numeric_grade  pollscore  ...  \
# 0  The New York Times/Siena College            3.0       -1.5  ...
# 1  The New York Times/Siena College            3.0       -1.5  ...
# 2  The New York Times/Siena College            3.0       -1.5  ...
# 3  The New York Times/Siena College            3.0       -1.5  ...
# 4  The New York Times/Siena College            3.0       -1.5  ...
#
#   election_date    stage nationwide_batch ranked_choice_reallocated  \
# 0       11/5/24  general            False                     False
# 1       11/5/24  general            False                     False
# 2       11/5/24  general            False                     False
# 3       11/5/24  general            False                     False
# 4       11/5/24  general            False                     False
#
#   ranked_choice_round  party   answer candidate_id     candidate_name   pct
# 0                 NaN    DEM    Biden        19368          Joe Biden  45.0
# 1                 NaN    REP    Trump        16651       Donald Trump  46.0
# 2                 NaN    DEM    Biden        19368          Joe Biden  40.0
# 3                 NaN    REP    Trump        16651       Donald Trump  42.0
# 4                 NaN    IND  Kennedy        31042  Robert F. Kennedy   2.0
#
# [5 rows x 48 columns]

# %%
# %%sql
# SELECT *
# FROM
#     (SELECT
#         state,
#         CAST(end_date as DATE) as enddate,
#         poll_id,
#         question_id,
#         row_number() OVER (PARTITION BY state ORDER BY CAST(end_date as DATE) DESC) as poll_number,
#         SUM(CASE WHEN candidate_id = 19368 then pct else 0 END) as BIDEN,
#         SUM(CASE WHEN candidate_id = 16651 then pct else 0 END) as TRUMP,
#     FROM polling_2024_initial
#     GROUP BY
#         state,
#         end_date,
#         poll_id,
#         question_id
#     )
# WHERE state = 'Michigan'
#     AND poll_number <= 15
# ORDER BY CAST(enddate as DATE) DESC
# Out:
#        state    enddate  poll_id  question_id  poll_number  BIDEN  TRUMP
# 0   Michigan 2024-03-28    86603       196031            1   39.8   43.0
# 1   Michigan 2024-03-28    86603       196030            2   43.7   48.0
# 2   Michigan 2024-03-24    86584       195855            3   45.0   48.0
# 3   Michigan 2024-03-24    86584       195841            4   37.0   39.0
# 4   Michigan 2024-03-24    86584       195848            5   40.0   45.0
# 5   Michigan 2024-03-19    86662       196535            6   45.0   51.0
# 6   Michigan 2024-03-18    86509       194890            7   42.0   50.0
# 7   Michigan 2024-03-18    86502       194847            8   40.6   43.2
# 8   Michigan 2024-03-18    86502       194846            9   49.7   50.3
# 9   Michigan 2024-03-18    86509       194891           10   34.0   40.0
# 10  Michigan 2024-03-18    86502       194848           11    0.0   44.6
# 11  Michigan 2024-03-17    86531       195234           12   39.0   41.0
# 12  Michigan 2024-03-16    86511       195212           13   44.0   47.0
# 13  Michigan 2024-03-16    86511       195213           14   42.0   44.0
# 14  Michigan 2024-03-12    86472       194661           15   36.0   41.0

# %%
query =  """
SELECT *
FROM
    (SELECT 
        state,
        CAST(end_date as DATE) as enddate,
        poll_id, 
        question_id,
        row_number() OVER (PARTITION BY state ORDER BY CAST(end_date as DATE) DESC) as poll_number,
        SUM(CASE WHEN candidate_id = 19368 then pct else 0 END) as BIDEN,
        SUM(CASE WHEN candidate_id = 16651 then pct else 0 END) as TRUMP,
    FROM polling_2024_initial
    GROUP BY 
        state,
        end_date,
        poll_id, 
        question_id
    )
WHERE state = 'Michigan'
    AND poll_number <= 15
ORDER BY CAST(enddate as DATE) DESC
"""

# %%
result = conn.execute(query)

# %%
polling_2024_updated = pd.DataFrame(result.fetchall(), columns=[x[0] for x in result.description])
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
polling_2024_updated.head()
# Out:
#       state     enddate  poll_id  question_id  poll_number  BIDEN  TRUMP
# 0  Michigan  2024-03-28    86603       196030            1   43.7   48.0
# 1  Michigan  2024-03-28    86603       196031            2   39.8   43.0
# 2  Michigan  2024-03-24    86584       195841            3   37.0   39.0
# 3  Michigan  2024-03-24    86584       195848            4   40.0   45.0
# 4  Michigan  2024-03-24    86584       195855            5   45.0   48.0
