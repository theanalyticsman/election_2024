# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_polls_to_dataframe(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all tables containing poll data
        tables = soup.find_all('table', class_='wikitable')

        poll_data = []
        header_row = ['Poll source', 'Date administered', 'Democrat', '%', 'Republican', '%', 'Lead margin', 'Sample size', 'Margin of error', 'state']
        poll_data.append(header_row)


        for table in tables:
            # Extract state name
            state_header = table.find_previous('h2')
            if state_header:
                state = state_header.text
                state = state.replace('[edit]','')
            else:
                continue

            # Extract rows from the table
            t = load_table(table, 'state',state)
            poll_count = 1
            for row in t:
                if row != header_row and len(row) == len(header_row):
                    if poll_count <= 15:
                        print(row)
                        poll_data.append(row)
                        poll_count += 1
    
        return poll_data

    else:
        print("Error fetching the webpage. Status code:", response.status_code)
        return None

def load_table(table, descriptor_title = 'none', descriptor = 'none'):
    t = table
    table_data = []
    row_data = []
    rows = t.find_all('tr')
    heads = t.find_all('th')
    heads = [head.text.strip() for head in heads]
    if descriptor_title != 'none':
        heads.append(descriptor_title)
    
    table_data.append(heads)


    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        if descriptor != 'none':
            cols.append(descriptor)
        if len(cols) > 1:
            table_data.append(cols)         
    return table_data

# %%
url = 'https://en.wikipedia.org/wiki/Statewide_opinion_polling_for_the_2016_United_States_presidential_election'
polls = scrape_polls_to_dataframe(url)
polling = pd.DataFrame(polls)
# Out:
# ['News-5/Strategy Research[1]', 'September 27, 2016', 'Hillary Clinton', '32%', 'Donald Trump', '48%', '16', '3,000', '± 2.0%', 'Alabama']
# ['Alaska Survey Research[2]', 'September 28 – October 2, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '46%', '4', '660', '± 3.8%', 'Alaska']
# ['NBC News/Wall Street Journal/Marist[6]', 'October 30 – November 1, 2016', 'Hillary Clinton', '41%', 'Donald Trump', '46%', '5', '719', '± 3.7%', 'Arizona']
# ['Ipsos/Reuters[8]', 'October 6–18, 2016', 'Hillary Clinton', '38%', 'Donald Trump', '45%', '7', '1,538', '± 2.8%', 'Arizona']
# ['NBC News/Wall Street Journal/Marist[9]', 'September 6–8, 2016', 'Hillary Clinton', '41%', 'Donald Trump', '42%', '1', '649', '± 3.8%', 'Arizona']
# ['University of Arkansas[27]', 'October 18–25, 2016', 'Hillary Clinton', '36%', 'Donald Trump', '59%', '23', '800', '± 4.1%', 'Arkansas']
# ['USC Dornsife/Los Angeles Times[31]', 'October 22–30, 2016', 'Hillary Clinton', '58%', 'Donald Trump', '32%', '26', '1,365', '± 2.3%', 'California']
# ['Public Policy Polling[43]', 'November 3–4, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '45%', '5', '704', '± 3.7%', 'Colorado']
# ['University of Denver[44]', 'October 29–31, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '41%', '1', '550', '± 4.2%', 'Colorado']
# ['Quinnipiac University[45]', 'October 10–16, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '40%', '11', '685', '± 3.7%', 'Colorado']
# ['Public Policy Polling[46]', 'September 27–28, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '44%', '7', '694', '± 3.7%', 'Colorado']
# ['CNN/ORC[47]', 'September 20–25, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '47%', '2', '784', '± 3.5%', 'Colorado']
# ['Quinnipiac University[48]', 'September 13–21, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '47%', 'Tied', '644', '± 3.9%', 'Colorado']
# ['Colorado Mesa University/Rocky Mountain PBS[49]', 'September 14–18, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '35%', '9', '540', '± 5.3%', 'Colorado']
# ['NBC News/Wall Street Journal/Marist[6]', 'October 30 – November 1, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '47%', '1', '707', '±3.7%', 'Georgia']
# ['Quinnipiac University[62]', 'October 20–26, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '46%', 'Tied', '707', '± 3.7%', 'Georgia']
# ['Quinnipiac University[48]', 'September 13–21, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '50%', '6', '638', '± 3.9%', 'Georgia']
# ['NBC News/Wall Street Journal/Marist[9]', 'September 6–8, 2016', 'Hillary Clinton', '43%', 'Donald Trump', '46%', '3', '625', '± 3.9%', 'Georgia']
# ['NBC News/Wall Street Journal/Marist[9]', 'September 6–8, 2016', 'Hillary Clinton', 'Donald Trump', '44%', 'Gary Johnson', '2', '625', '± 3.9%', 'Georgia']
# ['Loras College[80]', 'October 26–27, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '37%', '11', '600', '± 4.0%', 'Illinois']
# ['Loras College[81]', 'September 13–16, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '33%', '14', '600', '± 4.0%', 'Illinois']
# ['WTHR/Howey Politics Indiana[96]', 'September 6–8, 2016', 'Hillary Clinton', '36%', 'Donald Trump', 'Gary Johnson', '7', '600', '± 4%', 'Indiana']
# ['Simpson College/RABA Research[98]', 'November 1–2, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '46%', '2', '1,076', '± 3.0%', 'Iowa']
# ['Quinnipiac University[62]', 'October 20–26, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '47%', '1', '791', '± 3.5%', 'Iowa']
# ['Loras College[99]', 'September 20–22, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '42%', 'Tied', '491', '± 4.4%', 'Iowa']
# ['Quinnipiac University[48]', 'September 13–21, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '50%', '6', '612', '± 4%', 'Iowa']
# ['Simpson College/RABA Research[100]', 'September 6–8, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '43%', '1', '1,054', '± 3.0%', 'Iowa']
# ['Fort Hays State University[106]', 'November 1–3, 2016', 'Hillary Clinton', '34%', 'Donald Trump', '58%', '24', '313', '± 5.5%', 'Kansas']
# ['RunSwitch PR[110]', 'October 26–28, 2016', 'Hillary Clinton', '32%', 'Donald Trump', '56%', '24', '811', '± 3.44%', 'Kentucky']
# ["Maine People's Resource Center[118]", 'November 2–3, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '41%', '9', '855', '± 3.4%', 'Maine']
# ["Maine People's Resource Center[119]", 'October 24–26, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '40%', '7', '812', '± 3.4%', 'Maine']
# ["Maine People's Resource Center[120]", 'October 14–15, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '39%', '10', '890', '± 3.3%', 'Maine']
# ['Western New England University[128]', 'September 24 – October 3, 2016', 'Hillary Clinton', '65%', 'Donald Trump', '30%', '35', '403', '± 5.0%', 'Massachusetts']
# ['WBUR/MassINC[129]', 'September 7–10, 2016', 'Hillary Clinton', '60%', 'Donald Trump', '31%', '29', '506', '± 4.4%', 'Massachusetts']
# ['Public Policy Polling[43]', 'November 3–4, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '44%', '6', '957', '± 3.2%', 'Michigan']
# ['Fox 2 Detroit/Mitchell Poll[137]', 'October 31, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '45%', '6', '737', '± 3.61%', 'Michigan']
# ['Michigan State University[139]', 'September 1 – October 30, 2016', 'Hillary Clinton', '52%', 'Donald Trump', '32%', '20', '746', '± 3.6%', 'Michigan']
# ['Fox 2 Detroit/Mitchell Poll[140]', 'October 25, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '44%', '6', '1,030', '± 2.78%', 'Michigan']
# ['EPIC-MRA[141]', 'October 22–25, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '37%', '8', '600', '± 4.0%', 'Michigan']
# ['Fox 2 Detroit/Mitchell Poll[144]', 'October 18, 2016', 'Hillary Clinton', '53%', 'Donald Trump', '41%', '12', '1,102', '± 2.59%', 'Michigan']
# ['Ipsos/Reuters[145]', 'October 6–17, 2016', 'Hillary Clinton', '40%', 'Donald Trump', '36%', '4', '1,370', '± 3.0%', 'Michigan']
# ['Detroit News[146]', 'October 10–11, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '33%', '14', '600', '± 4.0%', 'Michigan']
# ['Fox 2 Detroit/Mitchell Poll[147]', 'September 27, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '44%', '5', '1,956', '± 2.2%', 'Michigan']
# ['EPIC-MRA[148]', 'September 10–13, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '38%', '4', '600', '± 4.0%', 'Michigan']
# ['Fox 2 Detroit/Mitchell Poll[149]', 'September 6–7, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '42%', '5', '940', '± 3.2%', 'Michigan']
# ['SurveyUSA/KSTP-TV[157]', 'October 22–26, 2016', 'Hillary Clinton', '53%', 'Donald Trump', '42%', '11', '656', '± 3.9%', 'Minnesota']
# ['SurveyUSA/KSTP-TV[158]', 'September 16–20, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '43%', '6', '625', '± 4%', 'Minnesota']
# ['Public Policy Polling[161]', 'October 31 – November 1, 2016', 'Hillary Clinton', '41%', 'Donald Trump', '52%', '11', '1,083', '± 3.0%', 'Missouri']
# ['MO Scout/BK Strategies[162]', 'October 27–28, 2016', 'Hillary Clinton', '39%', 'Donald Trump', '53%', '14', '1,698', '± 2.38%', 'Missouri']
# ['Public Policy Polling[161]', 'October 31 – November 1, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '45%', '3', '688', '± 3.7%', 'Nevada']
# ['CNN/ORC[179]', 'October 27 – November 1, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '51%', '6', '790', '± 3.5%', 'Nevada']
# ['NBC News/Wall Street Journal/Marist College[180]', 'October 20–24, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '45%', 'Tied', '707', '±3.7%', 'Nevada']
# ['CNN/ORC[181]', 'October 10–15, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '46%', '4', '698', '± 3.5%', 'Nevada']
# ['Clarity Campaign Labs[182]', 'October 10–11, 2016', 'Hillary Clinton', '43%', 'Donald Trump', '43%', 'Tied', '1,010', '± 3.1%', 'Nevada']
# ['Public Policy Polling[183]', 'October 10–11, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '43%', '4', '986', '± 3.1%', 'Nevada']
# ['Fox News[184]', 'September 18–20, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '46%', '4', '704', '± 3.5%', 'Nevada']
# ['Greenberg Quinlan Rosner[185]', 'September 10–19, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '46%', '3', '400', '± 4.9%', 'Nevada']
# ['NBC News/Wall Street Journal/Marist[9]', 'September 6–8, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '44%', '1', '627', '± 3.9%', 'Nevada']
# ['Public Policy Polling[186]', 'September 6–7, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '42%', '3', '815', '± 3.4%', 'Nevada']
# ['UMass Lowell/7News[205]', 'October 28 – November 2, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '45%', '1', '695', '± 4.28%', 'New Hampshire']
# ['Public Policy Polling[161]', 'October 31 – November 1, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '43%', '5', '781', '± 3.5%', 'New Hampshire']
# ['MassInc/WBUR[206]', 'October 29 – November 1, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '44%', '2', '500', '± 4.4%', 'New Hampshire']
# ['NH Journal', 'October 26–28, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '47%', '1', '408', '± 5.1%', 'New Hampshire']
# ['NBC News/Wall Street Journal/Marist College[180]', 'October 20–24, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '39%', '8', '768', '±3.5%', 'New Hampshire']
# ['MassInc/WBUR[207]', 'October 10–12, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '41%', '5', '501', '± 4.4%', 'New Hampshire']
# ['Public Policy Polling[208]', 'October 7–9, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '37%', '11', '600', '± 4%', 'New Hampshire']
# ['MassInc/WBUR[209]', 'September 27–29, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '38%', '9', '502', '± 4.4%', 'New Hampshire']
# ['GBA Strategies[210]', 'September 25–27, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '40%', '6', '600', '± 4.0%', 'New Hampshire']
# ['NBC News/Wall Street Journal/Marist[9]', 'September 6–8, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '41%', '1', '737', '± 3.6%', 'New Hampshire']
# ['Fairleigh Dickinson University[223]', 'October 12–16, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '40%', '11', '579', '± 4.3%', 'New Jersey']
# ['Stockton College[224]', 'September 22–29, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '40%', '6', '638', '± 3.9%', 'New Jersey']
# ['NBC 4 New York/Wall Street Journal/Marist[234]', 'September 21–23, 2016', 'Hillary Clinton', '57%', 'Donald Trump', '33%', '24', '676', '± 3.8%', 'New York']
# ['Quinnipiac University[238]', 'November 3–6, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '45%', '3', '870', '± 3.3%', 'North Carolina']
# ['Public Policy Polling[161]', 'October 31 – November 1, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '47%', '2', '1,169', '± 2.9%', 'North Carolina']
# ['NBC News/Wall Street Journal/Marist[240]', 'October 25–26, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '44%', '6', '780', '± 3.5%', 'North Carolina']
# ['New York Times Upshot/Siena College[241]', 'October 20–23, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '41%', '8', '792', '± 3.5%', 'North Carolina']
# ['Public Policy Polling[242]', 'October 21–22, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '46%', '3', '875', '± 3.3%', 'North Carolina']
# ['Ipsos/Reuters[243]', 'October 6–19, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '43%', '2', '1,233', '± 3.2%', 'North Carolina']
# ['NBC News/Wall Street Journal/Marist[246]', 'October 10–12, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '43%', '5', '743', '± 3.6%', 'North Carolina']
# ['Bloomberg/Selzer[247]', 'September 29 – October 2, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '45%', '1', '805', '± 3.5%', 'North Carolina']
# ['Quinnipiac University[248]', 'September 27 – October 2, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '46%', '3', '507', '± 4.4%', 'North Carolina']
# ['Fox News[249]', 'September 18–20, 2016', 'Hillary Clinton', '42%', 'Donald Trump', '47%', '5', '734', '± 3.9%', 'North Carolina']
# ['Public Policy Polling[250]', 'September 18–20, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '47%', 'Tied', '1,024', '± 3.1%', 'North Carolina']
# ['Greenberg Quinlan Rosner[185]', 'September 10–19, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '45%', '3', '400', '± 4.9%', 'North Carolina']
# ['Public Policy Polling[242]', 'October 21–22, 2016', 'Hillary Clinton', 'Donald Trump', '44%', 'Gary Johnson', '3', '875', '± 3.3%', 'North Carolina']
# ['Columbus Dispatch[273]', 'October 27 – November 5, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '47%', '1', '1,151', '±2.9%', 'Ohio']
# ['Quinnipiac University[239]', 'October 27 – November 1, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '47%', '3', '589', '± 4.0%', 'Ohio']
# ['Quinnipiac University[45]', 'October 10–16, 2016', 'Hillary Clinton', '47%', 'Donald Trump', '48%', '1', '624', '± 3.9%', 'Ohio']
# ['NBC News/Wall Street Journal/Marist[246]', 'October 10–12, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '45%', 'Tied', '724', '± 3.6%', 'Ohio']
# ['Ipsos/Reuters[275]', 'October 6–12, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '41%', '3', '1,200', '±3.2%', 'Ohio']
# ['Baldwin Wallace University[276]', 'October 9–11, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '38%', '10', '1,152', '± 3%', 'Ohio']
# ['TargetSmart/William and Mary[278]', 'October 3–6, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '43%', '3', '812', '±\xa0%', 'Ohio']
# ['Quinnipiac University[248]', 'September 27 – October 2, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '49%', '3', '497', '± 4.4%', 'Ohio']
# ['Target Smart/William & Mary[280]', 'September 15–22, 2016', 'Hillary Clinton', '43%', 'Donald Trump', '40%', '3', '652', '±\xa0%', 'Ohio']
# ['Fox News[281]', 'September 18–20, 2016', 'Hillary Clinton', '40%', 'Donald Trump', '45%', '5', '737', '± 3.5%', 'Ohio']
# ['Greenberg Quinlan Rosner[185]', 'September 10–19, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '46%', 'Tied', '400', '± 4.9%', 'Ohio']
# ['Bloomberg/Selzer[282]', 'September 9–12, 2016', 'Hillary Clinton', '43%', 'Donald Trump', '48%', '5', '802', '± 3.5%', 'Ohio']
# ['CNN/ORC[283]', 'September 7–12, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '50%', '4', '769', '± 3.5%', 'Ohio']
# ['Monmouth University[291]', 'October 1–4, 2016', 'Hillary Clinton', 'Donald Trump', 'Gary Johnson', '5%', 'Jill Stein', '405', '± 4.9%', 'Ohio']
# ['Anzalone Liszt Grove[279]', 'September 27 – October 2, 2016', 'Hillary Clinton', 'Donald Trump', 'Gary Johnson', '8%', 'Jill Stein', '800', '± 3.46%', 'Ohio']
# ['Morning Call/Muhlenberg College[304]', 'October 30 – November 4, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '42%', '6', '420', '± 5.5%', 'Pennsylvania']
# ['CNN/ORC[305]', 'October 27 – November 1, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '46%', '5', '799', '± 3.5%', 'Pennsylvania']
# ['Quinnipiac University[239]', 'October 27 – November 1, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '44%', '6', '612', '± 4.0%', 'Pennsylvania']
# ['Gravis Marketing/One America News Network[306]', 'October 31, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '49%', '2', '2,606', '± 1.9%', 'Pennsylvania']
# ['Morning Call/Muhlenberg College[307]', 'October 20–26, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '41%', '5', '420', '± 5.5%', 'Pennsylvania']
# ['Ipsos/Reuters[308]', 'October 6–17, 2016', 'Hillary Clinton', '45%', 'Donald Trump', '39%', '6', '1,467', '±2.9%', 'Pennsylvania']
# ['Quinnipiac University[248]', 'September 27 – October 2, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '43%', '5', '535', '± 4.2%', 'Pennsylvania']
# ['CNN/ORC[311]', 'September 20–25, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '47%', '3', '771', '± 3.5%', 'Pennsylvania']
# ['Greenberg Quinlan Rosner[185]', 'September 10–19, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '42%', '9', '400', '± 4.9%', 'Pennsylvania']
# ['MTSU[338]', 'September 28 – October 2, 2016', 'Hillary Clinton', '40%', 'Donald Trump', '50%', '10', '472', '± 5.0%', 'Tennessee']
# ['NBC News/Wall Street Journal/Marist[6]', 'October 30 – November 1, 2016', 'Hillary Clinton', '41%', 'Donald Trump', '49%', '8', '679', '± 3.8%', 'Texas']
# ['Texas Lyceum[341]', 'September 1–11, 2016', 'Hillary Clinton', '36%', 'Donald Trump', '42%', '6', '502', '± 4.37%', 'Texas']
# ['Public Policy Polling[43]', 'November 3–4, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '45%', '6', '1,238', '± 2.8%', 'Virginia']
# ['Roanoke College[369]', 'October 29 – November 1, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '40%', '9', '654', '± 3.8%', 'Virginia']
# ['Washington Post/Schar School[370]', 'October 27–30, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '45%', '6', '1,024', '± 3.5%', 'Virginia']
# ['Hampton University[371]', 'October 26–30, 2016', 'Hillary Clinton', '41%', 'Donald Trump', '44%', '3', '802', '± 4.57%', 'Virginia']
# ['Winthrop University[372]', 'October 23–30, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '43%', '6', '712', '± 3.6%', 'Virginia']
# ['Quinnipiac University[62]', 'October 20–26, 2016', 'Hillary Clinton', '53%', 'Donald Trump', '40%', '13', '749', '± 3.6%', 'Virginia']
# ['Hampton University[373]', 'September 28 – October 2, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '34%', '12', '800', '± 4.4%', 'Virginia']
# ['Public Policy Polling[46]', 'September 27–28, 2016', 'Hillary Clinton', '49%', 'Donald Trump', '43%', '6', '811', '± 3.4%', 'Virginia']
# ['Christopher Newport University[374]', 'September 15–23, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '38%', '10', '1,003', '± 3.9%', 'Virginia']
# ['Quinnipiac University[48]', 'September 13–21, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '43%', '7', '659', '± 3.8%', 'Virginia']
# ['Roanoke College[375]', 'September 11–20, 2016', 'Hillary Clinton', '51%', 'Donald Trump', '40%', '11', '841', '± 3.4%', 'Virginia']
# ['University of Mary Washington[376]', 'September 6–12, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '41%', '5', '685', '± 4.4%', 'Virginia']
# ['Public Policy Polling[377]', 'September 9–11, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '42%', '8', '878', '± 3.3%', 'Virginia']
# ['Insights West[12]', 'November 4–6, 2016', 'Hillary Clinton', '55%', 'Donald Trump', '39%', '16', '402', '± 4.9%', 'Washington']
# ['Strategies 360[390]', 'September 29 – October 3, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '33%', '17', '500', '± 4.4%', 'Washington']
# ['Garin-Hart-Yang[393]', 'September 13–17, 2016', 'Hillary Clinton', '28%', 'Donald Trump', '60%', '32', '500', '± 5.0%', 'West Virginia']
# ['Public Policy Polling[161]', 'October 31 – November 1, 2016', 'Hillary Clinton', '48%', 'Donald Trump', '41%', '7', '891', '± 3.3%', 'Wisconsin']
# ['Loras College[395]', 'October 31 – November 1, 2016', 'Hillary Clinton', '44%', 'Donald Trump', '42%', '2', '500', '± 4.4%', 'Wisconsin']
# ['Public Policy Polling[396]', 'October 18–19, 2016', 'Hillary Clinton', '50%', 'Donald Trump', '38%', '12', '804', '± 3.9%', 'Wisconsin']
# ['Marquette University[397]', 'October 6–9, 2016', 'Hillary Clinton', '46%', 'Donald Trump', '42%', '4', '878', '± 3.9%', 'Wisconsin']

# %%
polling.head()
polling.columns = polling.iloc[0]
polling = polling[1:]
polling.loc[polling.state == 'Michigan']
# Out:
# 0                        Poll source               Date administered  \
# 35         Public Policy Polling[43]              November 3–4, 2016
# 36  Fox 2 Detroit/Mitchell Poll[137]                October 31, 2016
# 37    Michigan State University[139]  September 1 – October 30, 2016
# 38  Fox 2 Detroit/Mitchell Poll[140]                October 25, 2016
# 39                     EPIC-MRA[141]             October 22–25, 2016
# 40  Fox 2 Detroit/Mitchell Poll[144]                October 18, 2016
# 41                Ipsos/Reuters[145]              October 6–17, 2016
# 42                 Detroit News[146]             October 10–11, 2016
# 43  Fox 2 Detroit/Mitchell Poll[147]              September 27, 2016
# 44                     EPIC-MRA[148]           September 10–13, 2016
# 45  Fox 2 Detroit/Mitchell Poll[149]             September 6–7, 2016
#
# 0          Democrat    %    Republican    % Lead margin Sample size  \
# 35  Hillary Clinton  50%  Donald Trump  44%           6         957
# 36  Hillary Clinton  51%  Donald Trump  45%           6         737
# 37  Hillary Clinton  52%  Donald Trump  32%          20         746
# 38  Hillary Clinton  50%  Donald Trump  44%           6       1,030
# 39  Hillary Clinton  45%  Donald Trump  37%           8         600
# 40  Hillary Clinton  53%  Donald Trump  41%          12       1,102
# 41  Hillary Clinton  40%  Donald Trump  36%           4       1,370
# 42  Hillary Clinton  47%  Donald Trump  33%          14         600
# 43  Hillary Clinton  49%  Donald Trump  44%           5       1,956
# 44  Hillary Clinton  42%  Donald Trump  38%           4         600
# 45  Hillary Clinton  47%  Donald Trump  42%           5         940
#
# 0  Margin of error     state
# 35          ± 3.2%  Michigan
# 36         ± 3.61%  Michigan
# 37          ± 3.6%  Michigan
# 38         ± 2.78%  Michigan
# 39          ± 4.0%  Michigan
# 40         ± 2.59%  Michigan
# 41          ± 3.0%  Michigan
# 42          ± 4.0%  Michigan
# 43          ± 2.2%  Michigan
# 44          ± 4.0%  Michigan
# 45          ± 3.2%  Michigan

# %%
polling.columns
# Out:
# Index(['Poll source', 'Date administered', 'Democrat', 'DEM_PERCENT',
#        'Republican', 'GOP_PERCENT', 'Lead margin', 'Sample size',
#        'Margin of error', 'state'],
#       dtype='object', name=0)

# %%
polling.columns.values[3] = 'DEM_PERCENT'
polling.columns.values[5] = 'GOP_PERCENT'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Donald Trump"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 polling.columns.values[3] = 'DEM_PERCENT'
#       2 polling.columns.values[5] = 'GOP_PERCENT'
# ----> 3 polling['DEM_PERCENT'] = pd.to_numeric(polling['DEM_PERCENT'].str.strip('%')) / 100
#       4 polling['GOP_PERCENT'] = pd.to_numeric(polling['GOP_PERCENT'].str.strip('%')) / 100
#
# File c:\Users\appar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
#     236         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     237         or isinstance(values_dtype, StringDtype)
#     238         and not values_dtype.storage == "pyarrow_numpy",
#     239     )
#     240 except (ValueError, TypeError):
#     241     if errors == "raise":
#
# File lib.pyx:2433, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Donald Trump" at position 18

# %%
polling.to_csv('C:/Users/appar/OneDrive/jup_nb/polls_2016.csv')

# %%
polling_2016 = pd.read_csv('C:/Users/appar/OneDrive/jup_nb/polls_2016.csv')

# %%
polling_2016['DEM_PERCENT'] = pd.to_numeric(polling_2016['DEM_PERCENT'].str.strip('%')) / 100
polling_2016['GOP_PERCENT'] = pd.to_numeric(polling_2016['GOP_PERCENT'].str.strip('%')) / 100

# %%
import duckdb
# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
# %%sql
#
# SELECT
#     2016 as year,
#     state,
#     COUNT(*) as poll_count,
#     AVG(DEM_PERCENT) as dem_poll_avg,
#     AVG(GOP_PERCENT) as gop_poll_avg
# FROM polling_2016
# GROUP BY state
# Out:
#     year           state  poll_count  dem_poll_avg  gop_poll_avg
# 0   2016         Arizona           3      0.400000      0.443333
# 1   2016            Iowa           5      0.436000      0.456000
# 2   2016          Kansas           1      0.340000      0.580000
# 3   2016            Ohio          13      0.450769      0.451538
# 4   2016           Texas           2      0.385000      0.455000
# 5   2016          Alaska           1      0.420000      0.460000
# 6   2016         Georgia           4      0.447500      0.472500
# 7   2016       Minnesota           2      0.510000      0.425000
# 8   2016          Nevada          10      0.459000      0.451000
# 9   2016   New Hampshire          10      0.456000      0.415000
# 10  2016        Kentucky           1      0.320000      0.560000
# 11  2016        New York           1      0.570000      0.330000
# 12  2016        Virginia          13      0.487692      0.413846
# 13  2016           Maine           3      0.486667      0.400000
# 14  2016   Massachusetts           2      0.625000      0.305000
# 15  2016        Michigan          11      0.478182      0.396364
# 16  2016        Missouri           2      0.400000      0.525000
# 17  2016  North Carolina          12      0.475000      0.449167
# 18  2016    Pennsylvania           9      0.488889      0.436667
# 19  2016         Alabama           1      0.320000      0.480000
# 20  2016      California           1      0.580000      0.320000
# 21  2016        Colorado           7      0.477143      0.427143
# 22  2016        Illinois           2      0.475000      0.350000
# 23  2016        Arkansas           1      0.360000      0.590000
# 24  2016      Washington           2      0.525000      0.360000
# 25  2016   West Virginia           1      0.280000      0.600000
# 26  2016      New Jersey           2      0.485000      0.400000
# 27  2016       Tennessee           1      0.400000      0.500000
# 28  2016       Wisconsin           4      0.470000      0.407500

# %%
query_output = """
SELECT 
    2016 as year,
    state,
    COUNT(*) as poll_count, 
    AVG(DEM_PERCENT) as dem_poll_avg,
    AVG(GOP_PERCENT) as gop_poll_avg
FROM polling_2016
GROUP BY state
"""

# %%
polls_2016 = conn.execute(query_output).fetchall()
polls_2016_df = pd.DataFrame(polls_2016, columns= [col[0] for col in conn.description])

# %%
polls_2016_df.to_csv('C:/Users/appar/OneDrive/jup_nb/polls_2016.csv')
